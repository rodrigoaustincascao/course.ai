# %% [markdown]
# # Projeto Final - Fase: Análise Exploratória dos Dados (EDA)

# %%
# !pip install pandas
# !pip install numpy
# !pip install scikit-learn
# !pip install seaborn
# !pip install plotly
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.1/15.1 MB 27.9 MB/s eta 0:00:0000:0100:01
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 356.2/356.2 kB 3.2 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 16.6 MB/s eta 0:00:00
# ...

# %%
# !pip install tqdm
# !pip install streamlit_pandas_profiling
# !pip install sweetviz
# !pip install ipywidgets
# !pip install ydata-profiling
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached visions-0.7.4-py3-none-any.whl.metadata (5.9 kB)
# ...
# Using cached visions-0.7.4-py3-none-any.whl (102 kB)
# ...
#   Attempting uninstall: visions
#     Found existing installation: visions 0.7.6
#     Uninstalling visions-0.7.6:
#       Successfully uninstalled visions-0.7.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ydata-profiling 4.9.0 requires visions[type_image_path]<0.7.7,>=0.7.5, but you have visions 0.7.4 which is incompatible.
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import pandas as pd

pd.set_option('display.float_format', '{:.5f}'.format)

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# import sweetviz as sv

from ydata_profiling import ProfileReport
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[13], line 10
#       6 import seaborn as sns
#       8 get_ipython().run_line_magic('matplotlib', 'inline')
# ---> 10 import sweetviz as sv
#
# ModuleNotFoundError: No module named 'sweetviz'

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Ingestão de Dados

# %%
df_data = pd.read_csv("../data/patient_data_100k_with_nan_outliers.csv")

# %% [markdown]
# # Análise Exploratória dos Dados (EDA)

# %%
df_data.head(5)
# Out:
#    ID Sexo Hand      Age      Edu     SES     MMSE     CDR       eTIV    nWBV  \
# 0   1    M    R 60.00000 19.00000 5.00000 29.00000 0.00000 1940.80000 0.75000
# 1   2    F    R 72.00000 14.00000 5.00000  3.00000 0.50000 1323.10000 0.74000
# 2   3    M    L 72.00000  5.00000 2.00000  9.00000 0.50000 1167.00000 0.74000
# 3   4    F    L 78.00000  8.00000 1.00000  1.00000 2.00000 1713.20000 0.73000
# 4   5    F    L 60.00000 16.00000 1.00000 22.00000 2.00000 1266.50000 0.65000
#
#       ASF    Delay
# 0 0.91000 13.00000
# 1 1.36000  2.00000
# 2 1.07000 19.00000
# 3 1.19000 20.00000
# 4 1.27000 23.00000

# %%
df_data.shape
# Out:
# (100000, 12)

# %%
df_data.describe()
# Out:
#                 ID         Age         Edu         SES        MMSE  \
# count 100000.00000 95005.00000 95000.00000 95000.00000 95007.00000
# mean   50000.50000    74.98164    12.48774     3.00100    15.00714
# std    28867.65780     9.29201     4.61381     1.41735     9.00143
# min        1.00000    -5.00000     5.00000     1.00000   -10.00000
# 25%    25000.75000    67.00000     8.00000     2.00000     7.00000
# 50%    50000.50000    75.00000    12.00000     3.00000    15.00000
# 75%    75000.25000    83.00000    16.00000     4.00000    23.00000
# max   100000.00000   150.00000    20.00000     5.00000    50.00000
#
#               CDR        eTIV        nWBV         ASF       Delay
# count 95000.00000 95006.00000 95000.00000 95000.00000 95000.00000
# mean      1.30225  1553.52331     0.70015     1.10038    12.01796
# std       1.07880   273.35027     0.05799     0.17316     7.20489
# min       0.00000  1100.00000     0.60000     0.80000     0.00000
# ...

# %%
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 12 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      100000 non-null  int64
#  1   Sexo    95000 non-null   object
#  2   Hand    95000 non-null   object
#  3   Age     95005 non-null   float64
#  4   Edu     95000 non-null   float64
#  5   SES     95000 non-null   float64
#  6   MMSE    95007 non-null   float64
#  7   CDR     95000 non-null   float64
#  8   eTIV    95006 non-null   float64
#  9   nWBV    95000 non-null   float64
#  10  ASF     95000 non-null   float64
#  11  Delay   95000 non-null   float64
# dtypes: float64(9), int64(1), object(2)
# memory usage: 9.2+ MB

# %%
for col in df_data.select_dtypes(include=['object', 'float64']).columns:
    print(f'{col}:\n{df_data[col].value_counts()}\n')
# Out:
# Sexo:
# Sexo
# M    47738
# F    47262
# Name: count, dtype: int64
#
# Hand:
# Hand
# L    47766
# R    47234
# Name: count, dtype: int64
#
# Age:
# Age
# 87.00000     3133
# 60.00000     3127
# 81.00000     3123
# 74.00000     3097
# 77.00000     3094
# 63.00000     3091
# 73.00000     3089
# 66.00000     3088
# 70.00000     3085
# 84.00000     3084
# 82.00000     3083
# 89.00000     3083
# 85.00000     3082
# 90.00000     3078
# 71.00000     3078
# 69.00000     3075
# 86.00000     3070
# 67.00000     3069
# 76.00000     3064
# 79.00000     3063
# 75.00000     3053
# 68.00000     3053
# 64.00000     3050
# 61.00000     3041
# 65.00000     3041
# 80.00000     3029
# 72.00000     3002
# 62.00000     2987
# 78.00000     2975
# 83.00000     2962
# 88.00000     2956
# -5.00000       58
# 150.00000      42
# Name: count, dtype: int64
#
# Edu:
# Edu
# 6.00000     6113
# 9.00000     5979
# 15.00000    5972
# 5.00000     5968
# 14.00000    5959
# 13.00000    5959
# 19.00000    5950
# ...

# %%
df_data.isna().sum()
# Out:
# ID          0
# Sexo     5000
# Hand     5000
# Age      4995
# Edu      5000
# SES      5000
# MMSE     4993
# CDR      5000
# eTIV     4994
# nWBV     5000
# ASF      5000
# Delay    5000
# dtype: int64

# %%
sns.pairplot(df_data);
plt.show()

# %% [markdown]
# # Relatório pandas-profiling

# %%
profile = ProfileReport(df_data, title = 'Profiling Report')
profile.to_notebook_iframe()

# %%
report = sv.analyze(df_data)

report.show_html('relatorio_sweetviz.html')
