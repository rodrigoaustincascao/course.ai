# %% [markdown]
# # Aprendizado de Máquina Automatizado (AutoML)
#
# Aprendizado de Máquina Automatizado (AutoML) refere-se ao processo de automatização do fluxo completo de aplicação de aprendizado de máquina a problemas do mundo real. Isso inclui tarefas como pré-processamento de dados, engenharia de características, seleção de modelos, ajuste de hiperparâmetros e implantação de modelos, tudo isso sem necessitar de uma intervenção manual extensa.
#
# Existem frameworks e bibliotecas que facilitam a comparação e avaliação de diferentes algoritmos de aprendizado de máquina. Eles oferecem ferramentas para automatizar o processo de treino, teste, validação e seleção do melhor modelo.

# %% [markdown]
# ## Benefícios do AutoML
#
# ### Economia de Tempo
#
# O desenvolvimento manual de modelos exige tempo e esforço significativos em tarefas como pré-processamento de dados, engenharia de características e ajuste de hiperparâmetros. O AutoML simplifica essas tarefas, permitindo que os usuários se concentrem em resolver problemas de maior nível e inovar.
#
# Estudos mostram que o AutoML pode reduzir o tempo gasto no desenvolvimento de modelos em até 90%, possibilitando uma iteração e experimentação mais rápidas.
#
# ### Acessibilidade
#
# As plataformas de AutoML abstraem as complexidades do aprendizado de máquina, tornando-o acessível a usuários sem expertise especializada em ciência de dados ou programação.
#
# O AutoML capacita especialistas de domínio, analistas de negócios e pesquisadores a aproveitarem o poder do aprendizado de máquina sem a necessidade de conhecimento técnico extenso.
#
# ### Escalabilidade
#
# Os frameworks de AutoML são projetados para lidar com grandes volumes de dados e ambientes de computação distribuída, permitindo uma escalabilidade perfeita para acomodar volumes crescentes de dados e demandas computacionais.
#
# O AutoML da Google, por exemplo, pode escalar para milhares de nós e processar petabytes de dados, tornando-o adequado para aplicações em nível empresarial.
#
# ## Limitações do AutoML
#
# ### Falta de Transparência
#
# O AutoML automatiza muitos aspectos do processo de desenvolvimento de modelos, o que pode obscurecer o funcionamento interno dos modelos resultantes. Essa falta de transparência pode tornar desafiador entender e interpretar as decisões dos modelos.
#
# Algumas plataformas de AutoML geram modelos complexos que são difíceis de interpretar, levantando preocupações sobre responsabilidade e confiabilidade, especialmente em indústrias regulamentadas como saúde e finanças.
#
# ### Personalização Limitada
#
# Embora o AutoML ofereça conveniência e eficiência, ele pode não fornecer o mesmo nível de personalização e ajuste fino que o desenvolvimento manual de modelos.
#
# Deve-se ponderar os benefícios da automação contra a necessidade de controle detalhado sobre a arquitetura do modelo e os hiperparâmetros.

# %% [markdown]
# <div style="border: 2px solid #4CAF50; padding: 15px; border-radius: 10px; background-color: #DFF2BF; color: #4F8A10; font-family: Arial;">
# AutoML e ML Manual têm suas próprias vantagens e desvantagens, e a melhor abordagem depende do contexto específico e dos requisitos do problema.
#
# AutoML é mais rápido e exige menos conhecimento especializado, mas pode produzir modelos menos precisos ou menos interpretáveis. É uma boa opção para problemas simples ou quando se tem tempo ou recursos limitados.
#
# ML manual requer mais expertise e tempo, mas permite um maior controle sobre o modelo e frequentemente resulta em soluções mais precisas e interpretáveis. É uma boa opção para problemas mais complexos ou quando há mais recursos e tempo disponíveis.
#
# </div>
#
# .

# %%
# !pip install pycaret
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pycaret
#   Downloading pycaret-3.3.2-py3-none-any.whl (486 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 486.1/486.1 kB 5.0 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: ipython>=5.5.0 in /home/nonrootuser/.local/lib/python3.11/site-packages (from pycaret) (8.26.0)
# Collecting ipywidgets>=7.6.5 (from pycaret)
#   Downloading ipywidgets-8.1.3-py3-none-any.whl (139 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.4/139.4 kB 14.4 MB/s eta 0:00:00
# Collecting tqdm>=4.62.0 (from pycaret)
#   Downloading tqdm-4.66.5-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 kB 3.6 MB/s eta 0:00:00
# Collecting numpy<1.27,>=1.21 (from pycaret)
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 29.2 MB/s eta 0:00:0000:0100:01
# Collecting pandas<2.2.0 (from pycaret)
#   Downloading pandas-2.1.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 30.7 MB/s eta 0:00:0000:0100:01
# Collecting jinja2>=3 (from pycaret)
#   Downloading jinja2-3.1.4-py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.3/133.3 kB 17.9 MB/s eta 0:00:00
# Collecting scipy<=1.11.4,>=1.6.1 (from pycaret)
#   Downloading scipy-1.11.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (36.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.4/36.4 MB 17.5 MB/s eta 0:00:0000:0100:01
# Collecting joblib<1.4,>=1.2.0 (from pycaret)
#   Downloading joblib-1.3.2-py3-none-any.whl (302 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.2/302.2 kB 24.5 MB/s eta 0:00:00
# Collecting scikit-learn>1.4.0 (from pycaret)
#   Downloading scikit_learn-1.5.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 23.9 MB/s eta 0:00:0000:0100:01
# Collecting pyod>=1.1.3 (from pycaret)
#   Downloading pyod-2.0.1.tar.gz (163 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.8/163.8 kB 21.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting imbalanced-learn>=0.12.0 (from pycaret)
#   Downloading imbalanced_learn-0.12.3-py3-none-any.whl (258 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.3/258.3 kB 10.7 MB/s eta 0:00:00
# Collecting category-encoders>=2.4.0 (from pycaret)
#   Downloading category_encoders-2.6.3-py2.py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.9/81.9 kB 13.7 MB/s eta 0:00:00
# Collecting lightgbm>=3.0.0 (from pycaret)
#   Downloading lightgbm-4.5.0-py3-none-manylinux_2_28_x86_64.whl (3.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 23.0 MB/s eta 0:00:0000:0100:01
# Collecting numba>=0.55.0 (from pycaret)
#   Downloading numba-0.60.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 22.9 MB/s eta 0:00:0000:0100:01
# Collecting requests>=2.27.1 (from pycaret)
#   Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 11.8 MB/s eta 0:00:00
# Requirement already satisfied: psutil>=5.9.0 in /home/nonrootuser/.local/lib/python3.11/site-packages (from pycaret) (6.0.0)
# Collecting markupsafe>=2.0.1 (from pycaret)
#   Downloading MarkupSafe-2.1.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (28 kB)
# Collecting importlib-metadata>=4.12.0 (from pycaret)
#   Downloading importlib_metadata-8.4.0-py3-none-any.whl (26 kB)
# Collecting nbformat>=4.2.0 (from pycaret)
#   Downloading nbformat-5.10.4-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 14.7 MB/s eta 0:00:00
# Collecting cloudpickle (from pycaret)
#   Downloading cloudpickle-3.0.0-py3-none-any.whl (20 kB)
# Collecting deprecation>=2.1.0 (from pycaret)
#   Downloading deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Collecting xxhash (from pycaret)
#   Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 8.6 MB/s eta 0:00:00
# Collecting matplotlib<3.8.0 (from pycaret)
#   Downloading matplotlib-3.7.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 23.4 MB/s eta 0:00:0000:0100:01
# Collecting scikit-plot>=0.3.7 (from pycaret)
#   Downloading scikit_plot-0.3.7-py3-none-any.whl (33 kB)
# Collecting yellowbrick>=1.4 (from pycaret)
#   Downloading yellowbrick-1.5-py3-none-any.whl (282 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 282.6/282.6 kB 26.9 MB/s eta 0:00:00
# Collecting plotly>=5.14.0 (from pycaret)
#   Downloading plotly-5.23.0-py3-none-any.whl (17.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 23.0 MB/s eta 0:00:0000:0100:01
# Collecting kaleido>=0.2.1 (from pycaret)
#   Downloading kaleido-0.2.1-py2.py3-none-manylinux1_x86_64.whl (79.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 14.7 MB/s eta 0:00:0000:0100:01
# Collecting schemdraw==0.15 (from pycaret)
#   Downloading schemdraw-0.15-py3-none-any.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 21.0 MB/s eta 0:00:00
# Collecting plotly-resampler>=0.8.3.1 (from pycaret)
#   Downloading plotly_resampler-0.10.0-py3-none-any.whl (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.7/80.7 kB 10.2 MB/s eta 0:00:00
# Collecting statsmodels>=0.12.1 (from pycaret)
#   Downloading statsmodels-0.14.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 25.0 MB/s eta 0:00:0000:010:01
# Collecting sktime==0.26.0 (from pycaret)
#   Downloading sktime-0.26.0-py3-none-any.whl (21.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.8/21.8 MB 24.1 MB/s eta 0:00:0000:0100:01
# Collecting tbats>=1.1.3 (from pycaret)
#   Downloading tbats-1.1.3-py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 7.3 MB/s eta 0:00:00
# Collecting pmdarima>=2.0.4 (from pycaret)
#   Downloading pmdarima-2.0.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 27.2 MB/s eta 0:00:0000:0100:01
# Collecting wurlitzer (from pycaret)
#   Downloading wurlitzer-3.1.1-py3-none-any.whl (8.6 kB)
# Requirement already satisfied: packaging in /home/nonrootuser/.local/lib/python3.11/site-packages (from sktime==0.26.0->pycaret) (24.1)
# Collecting scikit-base<0.8.0 (from sktime==0.26.0->pycaret)
#   Downloading scikit_base-0.7.8-py3-none-any.whl (130 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.1/130.1 kB 23.8 MB/s eta 0:00:00
# Collecting scikit-learn>1.4.0 (from pycaret)
#   Downloading scikit_learn-1.4.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 26.3 MB/s eta 0:00:0000:0100:01
# Collecting patsy>=0.5.1 (from category-encoders>=2.4.0->pycaret)
#   Downloading patsy-0.5.6-py2.py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.9/233.9 kB 44.3 MB/s eta 0:00:00
# Collecting threadpoolctl>=2.0.0 (from imbalanced-learn>=0.12.0->pycaret)
#   Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Collecting zipp>=0.5 (from importlib-metadata>=4.12.0->pycaret)
#   Downloading zipp-3.20.0-py3-none-any.whl (9.4 kB)
# Requirement already satisfied: decorator in /home/nonrootuser/.local/lib/python3.11/site-packages (from ipython>=5.5.0->pycaret) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/nonrootuser/.local/lib/python3.11/site-packages (from ipython>=5.5.0->pycaret) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /home/nonrootuser/.local/lib/python3.11/site-packages (from ipython>=5.5.0->pycaret) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /home/nonrootuser/.local/lib/python3.11/site-packages (from ipython>=5.5.0->pycaret) (3.0.47)
# Requirement already satisfied: pygments>=2.4.0 in /home/nonrootuser/.local/lib/python3.11/site-packages (from ipython>=5.5.0->pycaret) (2.18.0)
# Requirement already satisfied: stack-data in /home/nonrootuser/.local/lib/python3.11/site-packages (from ipython>=5.5.0->pycaret) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /home/nonrootuser/.local/lib/python3.11/site-packages (from ipython>=5.5.0->pycaret) (5.14.3)
# Requirement already satisfied: typing-extensions>=4.6 in /home/nonrootuser/.local/lib/python3.11/site-packages (from ipython>=5.5.0->pycaret) (4.12.2)
# Requirement already satisfied: pexpect>4.3 in /home/nonrootuser/.local/lib/python3.11/site-packages (from ipython>=5.5.0->pycaret) (4.9.0)
# Requirement already satisfied: comm>=0.1.3 in /home/nonrootuser/.local/lib/python3.11/site-packages (from ipywidgets>=7.6.5->pycaret) (0.2.2)
# Collecting widgetsnbextension~=4.0.11 (from ipywidgets>=7.6.5->pycaret)
#   Downloading widgetsnbextension-4.0.11-py3-none-any.whl (2.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 29.2 MB/s eta 0:00:0000:0100:01
# Collecting jupyterlab-widgets~=3.0.11 (from ipywidgets>=7.6.5->pycaret)
#   Downloading jupyterlab_widgets-3.0.11-py3-none-any.whl (214 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.4/214.4 kB 17.2 MB/s eta 0:00:00
# Collecting contourpy>=1.0.1 (from matplotlib<3.8.0->pycaret)
#   Downloading contourpy-1.2.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (306 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 306.0/306.0 kB 28.0 MB/s eta 0:00:00
# Collecting cycler>=0.10 (from matplotlib<3.8.0->pycaret)
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting fonttools>=4.22.0 (from matplotlib<3.8.0->pycaret)
#   Downloading fonttools-4.53.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 16.8 MB/s eta 0:00:0000:0100:01
# Collecting kiwisolver>=1.0.1 (from matplotlib<3.8.0->pycaret)
#   Downloading kiwisolver-1.4.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 23.2 MB/s eta 0:00:00a 0:00:01
# Collecting pillow>=6.2.0 (from matplotlib<3.8.0->pycaret)
#   Downloading pillow-10.4.0-cp311-cp311-manylinux_2_28_x86_64.whl (4.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 24.0 MB/s eta 0:00:0000:0100:01
# Collecting pyparsing>=2.3.1 (from matplotlib<3.8.0->pycaret)
#   Downloading pyparsing-3.1.2-py3-none-any.whl (103 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.2/103.2 kB 14.5 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.7 in /home/nonrootuser/.local/lib/python3.11/site-packages (from matplotlib<3.8.0->pycaret) (2.9.0.post0)
# Collecting fastjsonschema>=2.15 (from nbformat>=4.2.0->pycaret)
#   Downloading fastjsonschema-2.20.0-py3-none-any.whl (23 kB)
# Collecting jsonschema>=2.6 (from nbformat>=4.2.0->pycaret)
#   Downloading jsonschema-4.23.0-py3-none-any.whl (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.5/88.5 kB 17.5 MB/s eta 0:00:00
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/nonrootuser/.local/lib/python3.11/site-packages (from nbformat>=4.2.0->pycaret) (5.7.2)
# Collecting llvmlite<0.44,>=0.43.0dev0 (from numba>=0.55.0->pycaret)
#   Downloading llvmlite-0.43.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (43.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.9/43.9 MB 17.1 MB/s eta 0:00:0000:0100:01
# Collecting pytz>=2020.1 (from pandas<2.2.0->pycaret)
#   Downloading pytz-2024.1-py2.py3-none-any.whl (505 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 505.5/505.5 kB 36.0 MB/s eta 0:00:00
# Collecting tzdata>=2022.1 (from pandas<2.2.0->pycaret)
#   Downloading tzdata-2024.1-py2.py3-none-any.whl (345 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.4/345.4 kB 42.4 MB/s eta 0:00:00
# Collecting tenacity>=6.2.0 (from plotly>=5.14.0->pycaret)
#   Downloading tenacity-9.0.0-py3-none-any.whl (28 kB)
# Collecting dash>=2.9.0 (from plotly-resampler>=0.8.3.1->pycaret)
#   Downloading dash-2.17.1-py3-none-any.whl (7.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 28.7 MB/s eta 0:00:0000:0100:01
# Collecting orjson<4.0.0,>=3.8.0 (from plotly-resampler>=0.8.3.1->pycaret)
#   Downloading orjson-3.10.7-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (141 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.9/141.9 kB 22.7 MB/s eta 0:00:00
# Collecting tsdownsample>=0.1.3 (from plotly-resampler>=0.8.3.1->pycaret)
#   Downloading tsdownsample-0.1.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 24.9 MB/s eta 0:00:00a 0:00:01
# Collecting Cython!=0.29.18,!=0.29.31,>=0.29 (from pmdarima>=2.0.4->pycaret)
#   Downloading Cython-3.0.11-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 29.2 MB/s eta 0:00:00a 0:00:01
# Collecting urllib3 (from pmdarima>=2.0.4->pycaret)
#   Downloading urllib3-2.2.2-py3-none-any.whl (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.4/121.4 kB 24.7 MB/s eta 0:00:00
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /usr/local/lib/python3.11/site-packages (from pmdarima>=2.0.4->pycaret) (65.5.1)
# Collecting charset-normalizer<4,>=2 (from requests>=2.27.1->pycaret)
#   Downloading charset_normalizer-3.3.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.3/140.3 kB 20.1 MB/s eta 0:00:00
# Collecting idna<4,>=2.5 (from requests>=2.27.1->pycaret)
#   Downloading idna-3.7-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 12.6 MB/s eta 0:00:00
# Collecting certifi>=2017.4.17 (from requests>=2.27.1->pycaret)
#   Downloading certifi-2024.7.4-py3-none-any.whl (162 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.0/163.0 kB 20.5 MB/s eta 0:00:00
# Collecting Flask<3.1,>=1.0.4 (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret)
#   Downloading flask-3.0.3-py3-none-any.whl (101 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 19.9 MB/s eta 0:00:00
# Collecting Werkzeug<3.1 (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret)
#   Downloading werkzeug-3.0.3-py3-none-any.whl (227 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.3/227.3 kB 14.0 MB/s eta 0:00:00
# Collecting dash-html-components==2.0.0 (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret)
#   Downloading dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Collecting dash-core-components==2.0.0 (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret)
#   Downloading dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Collecting dash-table==5.0.0 (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret)
#   Downloading dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# Collecting retrying (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret)
#   Downloading retrying-1.3.4-py3-none-any.whl (11 kB)
# Requirement already satisfied: nest-asyncio in /home/nonrootuser/.local/lib/python3.11/site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (1.6.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/nonrootuser/.local/lib/python3.11/site-packages (from jedi>=0.16->ipython>=5.5.0->pycaret) (0.8.4)
# Collecting attrs>=22.2.0 (from jsonschema>=2.6->nbformat>=4.2.0->pycaret)
#   Downloading attrs-24.2.0-py3-none-any.whl (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.0/63.0 kB 8.6 MB/s eta 0:00:00
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema>=2.6->nbformat>=4.2.0->pycaret)
#   Downloading jsonschema_specifications-2023.12.1-py3-none-any.whl (18 kB)
# Collecting referencing>=0.28.4 (from jsonschema>=2.6->nbformat>=4.2.0->pycaret)
#   Downloading referencing-0.35.1-py3-none-any.whl (26 kB)
# Collecting rpds-py>=0.7.1 (from jsonschema>=2.6->nbformat>=4.2.0->pycaret)
#   Downloading rpds_py-0.20.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (354 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 354.8/354.8 kB 14.1 MB/s eta 0:00:00
# Requirement already satisfied: platformdirs>=2.5 in /home/nonrootuser/.local/lib/python3.11/site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat>=4.2.0->pycaret) (4.2.2)
# Requirement already satisfied: six in /home/nonrootuser/.local/lib/python3.11/site-packages (from patsy>=0.5.1->category-encoders>=2.4.0->pycaret) (1.16.0)
# Requirement already satisfied: ptyprocess>=0.5 in /home/nonrootuser/.local/lib/python3.11/site-packages (from pexpect>4.3->ipython>=5.5.0->pycaret) (0.7.0)
# Requirement already satisfied: wcwidth in /home/nonrootuser/.local/lib/python3.11/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=5.5.0->pycaret) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /home/nonrootuser/.local/lib/python3.11/site-packages (from stack-data->ipython>=5.5.0->pycaret) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/nonrootuser/.local/lib/python3.11/site-packages (from stack-data->ipython>=5.5.0->pycaret) (2.4.1)
# Requirement already satisfied: pure-eval in /home/nonrootuser/.local/lib/python3.11/site-packages (from stack-data->ipython>=5.5.0->pycaret) (0.2.3)
# Collecting itsdangerous>=2.1.2 (from Flask<3.1,>=1.0.4->dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret)
#   Downloading itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Collecting click>=8.1.3 (from Flask<3.1,>=1.0.4->dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret)
#   Downloading click-8.1.7-py3-none-any.whl (97 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.9/97.9 kB 12.1 MB/s eta 0:00:00
# Collecting blinker>=1.6.2 (from Flask<3.1,>=1.0.4->dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret)
#   Downloading blinker-1.8.2-py3-none-any.whl (9.5 kB)
# Building wheels for collected packages: pyod
#   Building wheel for pyod (setup.py) ... done
#   Created wheel for pyod: filename=pyod-2.0.1-py3-none-any.whl size=193273 sha256=6435fd98c56597f67e0c9f10d07d64f14f8edd6d9254eb38b61d85dd90fb6e4a
#   Stored in directory: /home/nonrootuser/.cache/pip/wheels/60/c9/a5/1c4c4f7da35f31ae2f79002aa0d84cf79ffb9fa17bc2b4ff15
# Successfully built pyod
# Installing collected packages: pytz, kaleido, fastjsonschema, dash-table, dash-html-components, dash-core-components, zipp, xxhash, wurlitzer, widgetsnbextension, urllib3, tzdata, tqdm, threadpoolctl, tenacity, scikit-base, schemdraw, rpds-py, retrying, pyparsing, pillow, orjson, numpy, markupsafe, llvmlite, kiwisolver, jupyterlab-widgets, joblib, itsdangerous, idna, fonttools, deprecation, Cython, cycler, cloudpickle, click, charset-normalizer, certifi, blinker, attrs, Werkzeug, tsdownsample, scipy, requests, referencing, plotly, patsy, pandas, numba, jinja2, importlib-metadata, contourpy, statsmodels, scikit-learn, matplotlib, lightgbm, jsonschema-specifications, Flask, yellowbrick, sktime, scikit-plot, pyod, pmdarima, jsonschema, ipywidgets, imbalanced-learn, dash, category-encoders, tbats, plotly-resampler, nbformat, pycaret
# Successfully installed Cython-3.0.11 Flask-3.0.3 Werkzeug-3.0.3 attrs-24.2.0 blinker-1.8.2 category-encoders-2.6.3 certifi-2024.7.4 charset-normalizer-3.3.2 click-8.1.7 cloudpickle-3.0.0 contourpy-1.2.1 cycler-0.12.1 dash-2.17.1 dash-core-components-2.0.0 dash-html-components-2.0.0 dash-table-5.0.0 deprecation-2.1.0 fastjsonschema-2.20.0 fonttools-4.53.1 idna-3.7 imbalanced-learn-0.12.3 importlib-metadata-8.4.0 ipywidgets-8.1.3 itsdangerous-2.2.0 jinja2-3.1.4 joblib-1.3.2 jsonschema-4.23.0 jsonschema-specifications-2023.12.1 jupyterlab-widgets-3.0.11 kaleido-0.2.1 kiwisolver-1.4.5 lightgbm-4.5.0 llvmlite-0.43.0 markupsafe-2.1.5 matplotlib-3.7.5 nbformat-5.10.4 numba-0.60.0 numpy-1.26.4 orjson-3.10.7 pandas-2.1.4 patsy-0.5.6 pillow-10.4.0 plotly-5.23.0 plotly-resampler-0.10.0 pmdarima-2.0.4 pycaret-3.3.2 pyod-2.0.1 pyparsing-3.1.2 pytz-2024.1 referencing-0.35.1 requests-2.32.3 retrying-1.3.4 rpds-py-0.20.0 schemdraw-0.15 scikit-base-0.7.8 scikit-learn-1.4.2 scikit-plot-0.3.7 scipy-1.11.4 sktime-0.26.0 statsmodels-0.14.2 tbats-1.1.3 tenacity-9.0.0 threadpoolctl-3.5.0 tqdm-4.66.5 tsdownsample-0.1.3 tzdata-2024.1 urllib3-2.2.2 widgetsnbextension-4.0.11 wurlitzer-3.1.1 xxhash-3.5.0 yellowbrick-1.5 zipp-3.20.0
#
# [notice] A new release of pip is available: 23.1.2 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip install tpot
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting tpot
#   Downloading TPOT-0.12.2-py3-none-any.whl (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.4/87.4 kB 1.6 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: numpy>=1.16.3 in /home/nonrootuser/.local/lib/python3.11/site-packages (from tpot) (1.26.4)
# Requirement already satisfied: scipy>=1.3.1 in /home/nonrootuser/.local/lib/python3.11/site-packages (from tpot) (1.11.4)
# Requirement already satisfied: scikit-learn>=1.4.1 in /home/nonrootuser/.local/lib/python3.11/site-packages (from tpot) (1.4.2)
# Collecting deap>=1.2 (from tpot)
#   Downloading deap-1.4.1.tar.gz (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 3.0 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Collecting update-checker>=0.16 (from tpot)
#   Downloading update_checker-0.18.0-py3-none-any.whl (7.0 kB)
# Requirement already satisfied: tqdm>=4.36.1 in /home/nonrootuser/.local/lib/python3.11/site-packages (from tpot) (4.66.5)
# Collecting stopit>=1.1.1 (from tpot)
#   Downloading stopit-1.1.2.tar.gz (18 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas>=0.24.2 in /home/nonrootuser/.local/lib/python3.11/site-packages (from tpot) (2.1.4)
# Requirement already satisfied: joblib>=0.13.2 in /home/nonrootuser/.local/lib/python3.11/site-packages (from tpot) (1.3.2)
# Collecting xgboost>=1.1.0 (from tpot)
#   Downloading xgboost-2.1.1-py3-none-manylinux_2_28_x86_64.whl (153.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.9/153.9 MB 981.9 kB/s eta 0:00:0000:0100:06
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/nonrootuser/.local/lib/python3.11/site-packages (from pandas>=0.24.2->tpot) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/nonrootuser/.local/lib/python3.11/site-packages (from pandas>=0.24.2->tpot) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /home/nonrootuser/.local/lib/python3.11/site-packages (from pandas>=0.24.2->tpot) (2024.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/nonrootuser/.local/lib/python3.11/site-packages (from scikit-learn>=1.4.1->tpot) (3.5.0)
# Requirement already satisfied: requests>=2.3.0 in /home/nonrootuser/.local/lib/python3.11/site-packages (from update-checker>=0.16->tpot) (2.32.3)
# Collecting nvidia-nccl-cu12 (from xgboost>=1.1.0->tpot)
#   Downloading nvidia_nccl_cu12-2.22.3-py3-none-manylinux2014_x86_64.whl (190.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.9/190.9 MB 8.6 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: six>=1.5 in /home/nonrootuser/.local/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=0.24.2->tpot) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/nonrootuser/.local/lib/python3.11/site-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/nonrootuser/.local/lib/python3.11/site-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/nonrootuser/.local/lib/python3.11/site-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/nonrootuser/.local/lib/python3.11/site-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (2024.7.4)
# Building wheels for collected packages: deap, stopit
#   Building wheel for deap (setup.py) ... done
#   Created wheel for deap: filename=deap-1.4.1-cp311-cp311-linux_x86_64.whl size=142190 sha256=4b9ee0e1aee108e660738e8664fd05cb289e01a337425efb64bd303bd7fbcbf7
#   Stored in directory: /home/nonrootuser/.cache/pip/wheels/f8/64/b8/65eacfbff3024ae2e2beb22e691d5c8abb89fbd863b8049b5f
#   Building wheel for stopit (setup.py) ... done
#   Created wheel for stopit: filename=stopit-1.1.2-py3-none-any.whl size=11938 sha256=bc99cc26c5dcead322bca357705caddf7813ed65168e92ca770c002d3ae7444b
#   Stored in directory: /home/nonrootuser/.cache/pip/wheels/da/77/2d/adbc56bc4db95ad80c6d4e71cd69e2d9d122174904342e3f7f
# Successfully built deap stopit
# Installing collected packages: stopit, nvidia-nccl-cu12, deap, xgboost, update-checker, tpot
# Successfully installed deap-1.4.1 nvidia-nccl-cu12-2.22.3 stopit-1.1.2 tpot-0.12.2 update-checker-0.18.0 xgboost-2.1.1
#
# [notice] A new release of pip is available: 23.1.2 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip install h2o
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting h2o
#   Downloading h2o-3.46.0.4.tar.gz (265.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.3/265.3 MB 7.1 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests in /home/nonrootuser/.local/lib/python3.11/site-packages (from h2o) (2.32.3)
# Collecting tabulate (from h2o)
#   Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/nonrootuser/.local/lib/python3.11/site-packages (from requests->h2o) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/nonrootuser/.local/lib/python3.11/site-packages (from requests->h2o) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/nonrootuser/.local/lib/python3.11/site-packages (from requests->h2o) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/nonrootuser/.local/lib/python3.11/site-packages (from requests->h2o) (2024.7.4)
# Building wheels for collected packages: h2o
#   Building wheel for h2o (setup.py) ... done
#   Created wheel for h2o: filename=h2o-3.46.0.4-py2.py3-none-any.whl size=265375579 sha256=b0a043d896e36c36a28a7ac0209d5e54f2b048e7b8a5c41342ba1f5aaf966035
#   Stored in directory: /home/nonrootuser/.cache/pip/wheels/be/76/58/759903214b4d4f3337d65741773477c8e2555d38683d0f4cf2
# Successfully built h2o
# Installing collected packages: tabulate, h2o
# Successfully installed h2o-3.46.0.4 tabulate-0.9.0
#
# [notice] A new release of pip is available: 23.1.2 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 3.5 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /home/nonrootuser/.local/lib/python3.11/site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in /home/nonrootuser/.local/lib/python3.11/site-packages (from seaborn) (2.1.4)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /home/nonrootuser/.local/lib/python3.11/site-packages (from seaborn) (3.7.5)
# Requirement already satisfied: contourpy>=1.0.1 in /home/nonrootuser/.local/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /home/nonrootuser/.local/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/nonrootuser/.local/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/nonrootuser/.local/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /home/nonrootuser/.local/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /home/nonrootuser/.local/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/nonrootuser/.local/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/nonrootuser/.local/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/nonrootuser/.local/lib/python3.11/site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /home/nonrootuser/.local/lib/python3.11/site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in /home/nonrootuser/.local/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
#
# [notice] A new release of pip is available: 23.1.2 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import r2_score

import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

import joblib
from joblib import dump

# %%
models_result = []

# %%
df_normalizado = pd.read_csv("../data/processed/predicao_cargas_trabalho_normalizado.csv")

X = df_normalizado.loc[:, df_normalizado.columns != 'casos_pendentes']
y = df_normalizado["casos_pendentes"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %% [markdown]
# <div style="background-color: #f0f8ff; padding: 7px; border-radius: 10px;">
# <h3>PyCaret</h3>
# </div>
#
# PyCaret é uma biblioteca de AutoML que fornece uma interface simplificada para comparação de modelos, tuning de hiperparâmetros e seleção de características.

# %%
from pycaret.regression import setup, compare_models, create_model, get_metrics, predict_model, evaluate_model, finalize_model, save_model, load_model

data_train = pd.concat([X_train, y_train], axis=1)
data_test = pd.concat([X_test, y_test], axis=1)

# Carregando o dataset de treino no PyCaret
reg = setup(data=data_train, target='casos_pendentes', session_id=123,  verbose=False)

# Comparando todos os modelos para escolher o melhor
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_5879e th {
#   text-align: left;
# }
# #T_5879e_row0_col0, #T_5879e_row0_col1, #T_5879e_row0_col6, #T_5879e_row1_col0, #T_5879e_row1_col1, #T_5879e_row1_col4, #T_5879e_row1_col6, #T_5879e_row2_col0, #T_5879e_row2_col4, #T_5879e_row3_col0, #T_5879e_row3_col1, #T_5879e_row3_col3, #T_5879e_row3_col4, #T_5879e_row3_col6, #T_5879e_row4_col0, #T_5879e_row4_col3, #T_5879e_row4_col4, #T_5879e_row4_col6, #T_5879e_row5_col0, #T_5879e_row5_col1, #T_5879e_row5_col2, #T_5879e_row5_col3, #T_5879e_row5_col4, #T_5879e_row5_col5, #T_5879e_row5_col6, #T_5879e_row6_col0, #T_5879e_row6_col1, #T_5879e_row6_col2, #T_5879e_row6_col3, #T_5879e_row6_col4, #T_5879e_row6_col5, #T_5879e_row6_col6, #T_5879e_row7_col0, #T_5879e_row7_col1, #T_5879e_row7_col2, #T_5879e_row7_col3, #T_5879e_row7_col4, #T_5879e_row7_col5, #T_5879e_row7_col6, #T_5879e_row8_col0, #T_5879e_row8_col1, #T_5879e_row8_col2, #T_5879e_row8_col3, #T_5879e_row8_col4, #T_5879e_row8_col5, #T_5879e_row8_col6, #T_5879e_row9_col0, #T_5879e_row9_col1, #T_5879e_row9_col2, #T_5879e_row9_col3, #T_5879e_row9_col4, #T_5879e_row9_col5, #T_5879e_row9_col6, #T_5879e_row10_col0, #T_5879e_row10_col1, #T_5879e_row10_col2, #T_5879e_row10_col3, #T_5879e_row10_col4, #T_5879e_row10_col5, #T_5879e_row10_col6, #T_5879e_row11_col0, #T_5879e_row11_col1, #T_5879e_row11_col2, #T_5879e_row11_col3, #T_5879e_row11_col4, #T_5879e_row11_col5, #T_5879e_row11_col6, #T_5879e_row12_col0, #T_5879e_row12_col1, #T_5879e_row12_col2, #T_5879e_row12_col3, #T_5879e_row12_col4, #T_5879e_row12_col5, #T_5879e_row12_col6, #T_5879e_row13_col0, #T_5879e_row13_col1, #T_5879e_row13_col2, #T_5879e_row13_col3, #T_5879e_row13_col4, #T_5879e_row13_col5, #T_5879e_row13_col6, #T_5879e_row14_col0, #T_5879e_row14_col1, #T_5879e_row14_col2, #T_5879e_row14_col3, #T_5879e_row14_col4, #T_5879e_row14_col5, #T_5879e_row14_col6, #T_5879e_row15_col0, #T_5879e_row15_col1, #T_5879e_row15_col2, #T_5879e_row15_col3, #T_5879e_row15_col4, #T_5879e_row15_col5, #T_5879e_row15_col6, #T_5879e_row16_col0, #T_5879e_row16_col1, #T_5879e_row16_col2, #T_5879e_row16_col3, #T_5879e_row16_col4, #T_5879e_row16_col5, #T_5879e_row16_col6, #T_5879e_row17_col0, #T_5879e_row17_col1, #T_5879e_row17_col2, #T_5879e_row17_col3, #T_5879e_row17_col4, #T_5879e_row17_col5, #T_5879e_row17_col6, #T_5879e_row18_col0, #T_5879e_row18_col1, #T_5879e_row18_col2, #T_5879e_row18_col3, #T_5879e_row18_col4, #T_5879e_row18_col5, #T_5879e_row18_col6 {
#   text-align: left;
# }
# #T_5879e_row0_col2, #T_5879e_row0_col3, #T_5879e_row0_col4, #T_5879e_row0_col5, #T_5879e_row1_col2, #T_5879e_row1_col3, #T_5879e_row1_col5, #T_5879e_row2_col1, #T_5879e_row2_col2, #T_5879e_row2_col3, #T_5879e_row2_col5, #T_5879e_row2_col6, #T_5879e_row3_col2, #T_5879e_row3_col5, #T_5879e_row4_col1, #T_5879e_row4_col2, #T_5879e_row4_col5 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_5879e_row0_col7, #T_5879e_row1_col7, #T_5879e_row2_col7, #T_5879e_row3_col7, #T_5879e_row4_col7, #T_5879e_row5_col7, #T_5879e_row6_col7, #T_5879e_row7_col7, #T_5879e_row8_col7, #T_5879e_row9_col7, #T_5879e_row10_col7, #T_5879e_row11_col7, #T_5879e_row12_col7, #T_5879e_row13_col7, #T_5879e_row14_col7, #T_5879e_row15_col7, #T_5879e_row16_col7, #T_5879e_row17_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_5879e_row18_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_5879e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5879e_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_5879e_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_5879e_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_5879e_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_5879e_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_5879e_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_5879e_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_5879e_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5879e_level0_row0" class="row_heading level0 row0" >huber</th>
#       <td id="T_5879e_row0_col0" class="data row0 col0" >Huber Regressor</td>
#       <td id="T_5879e_row0_col1" class="data row0 col1" >0.0556</td>
#       <td id="T_5879e_row0_col2" class="data row0 col2" >0.0053</td>
#       <td id="T_5879e_row0_col3" class="data row0 col3" >0.0725</td>
#       <td id="T_5879e_row0_col4" class="data row0 col4" >0.7907</td>
#       <td id="T_5879e_row0_col5" class="data row0 col5" >0.0497</td>
#       <td id="T_5879e_row0_col6" class="data row0 col6" >0.1376</td>
#       <td id="T_5879e_row0_col7" class="data row0 col7" >0.0310</td>
#     </tr>
#     <tr>
#       <th id="T_5879e_level0_row1" class="row_heading level0 row1" >br</th>
#       <td id="T_5879e_row1_col0" class="data row1 col0" >Bayesian Ridge</td>
#       <td id="T_5879e_row1_col1" class="data row1 col1" >0.0556</td>
#       <td id="T_5879e_row1_col2" class="data row1 col2" >0.0053</td>
#       <td id="T_5879e_row1_col3" class="data row1 col3" >0.0725</td>
#       <td id="T_5879e_row1_col4" class="data row1 col4" >0.7906</td>
#       <td id="T_5879e_row1_col5" class="data row1 col5" >0.0497</td>
#       <td id="T_5879e_row1_col6" class="data row1 col6" >0.1374</td>
#       <td id="T_5879e_row1_col7" class="data row1 col7" >0.0150</td>
#     </tr>
#     <tr>
#       <th id="T_5879e_level0_row2" class="row_heading level0 row2" >lr</th>
#       <td id="T_5879e_row2_col0" class="data row2 col0" >Linear Regression</td>
#       <td id="T_5879e_row2_col1" class="data row2 col1" >0.0555</td>
#       <td id="T_5879e_row2_col2" class="data row2 col2" >0.0053</td>
#       <td id="T_5879e_row2_col3" class="data row2 col3" >0.0725</td>
#       <td id="T_5879e_row2_col4" class="data row2 col4" >0.7905</td>
#       <td id="T_5879e_row2_col5" class="data row2 col5" >0.0497</td>
#       <td id="T_5879e_row2_col6" class="data row2 col6" >0.1373</td>
#       <td id="T_5879e_row2_col7" class="data row2 col7" >0.8540</td>
#     </tr>
#     <tr>
#       <th id="T_5879e_level0_row3" class="row_heading level0 row3" >ridge</th>
#       <td id="T_5879e_row3_col0" class="data row3 col0" >Ridge Regression</td>
#       <td id="T_5879e_row3_col1" class="data row3 col1" >0.0556</td>
#       <td id="T_5879e_row3_col2" class="data row3 col2" >0.0053</td>
#       <td id="T_5879e_row3_col3" class="data row3 col3" >0.0726</td>
#       <td id="T_5879e_row3_col4" class="data row3 col4" >0.7905</td>
#       <td id="T_5879e_row3_col5" class="data row3 col5" >0.0497</td>
#       <td id="T_5879e_row3_col6" class="data row3 col6" >0.1383</td>
#       <td id="T_5879e_row3_col7" class="data row3 col7" >0.0150</td>
#     </tr>
#     <tr>
#       <th id="T_5879e_level0_row4" class="row_heading level0 row4" >omp</th>
#       <td id="T_5879e_row4_col0" class="data row4 col0" >Orthogonal Matching Pursuit</td>
#       <td id="T_5879e_row4_col1" class="data row4 col1" >0.0555</td>
#       <td id="T_5879e_row4_col2" class="data row4 col2" >0.0053</td>
#       <td id="T_5879e_row4_col3" class="data row4 col3" >0.0726</td>
#       <td id="T_5879e_row4_col4" class="data row4 col4" >0.7904</td>
#       <td id="T_5879e_row4_col5" class="data row4 col5" >0.0497</td>
#       <td id="T_5879e_row4_col6" class="data row4 col6" >0.1377</td>
#       <td id="T_5879e_row4_col7" class="data row4 col7" >0.0120</td>
#     </tr>
#     <tr>
#       <th id="T_5879e_level0_row5" class="row_heading level0 row5" >gbr</th>
#       <td id="T_5879e_row5_col0" class="data row5 col0" >Gradient Boosting Regressor</td>
#       <td id="T_5879e_row5_col1" class="data row5 col1" >0.0573</td>
#       <td id="T_5879e_row5_col2" class="data row5 col2" >0.0055</td>
#       <td id="T_5879e_row5_col3" class="data row5 col3" >0.0741</td>
#       <td id="T_5879e_row5_col4" class="data row5 col4" >0.7812</td>
#       <td id="T_5879e_row5_col5" class="data row5 col5" >0.0508</td>
#       <td id="T_5879e_row5_col6" class="data r

# %%
best_model
# Out:
# HuberRegressor()

# %%
evaluate_model(best_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
predictions = predict_model(best_model, data=data_test)
# Out:
# <style type="text/css">
# </style>
# <table id="T_26803">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_26803_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_26803_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_26803_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_26803_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_26803_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_26803_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_26803_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_26803_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_26803_row0_col0" class="data row0 col0" >Huber Regressor</td>
#       <td id="T_26803_row0_col1" class="data row0 col1" >0.0555</td>
#       <td id="T_26803_row0_col2" class="data row0 col2" >0.0049</td>
#       <td id="T_26803_row0_col3" class="data row0 col3" >0.0703</td>
#       <td id="T_26803_row0_col4" class="data row0 col4" >0.8015</td>
#       <td id="T_26803_row0_col5" class="data row0 col5" >0.0476</td>
#       <td id="T_26803_row0_col6" class="data row0 col6" >0.1791</td>
#     </tr>
#   </tbody>
# </table>

# %%
predictions
# Out:
#       populacao  num_juizes  casos_recebidos  tipo_caso  \
# 1344   0.987008    0.473684         0.693484        0.0
# 3752   0.945715    0.894737         0.579244        0.0
# 252    0.137650    0.105263         0.806919        0.0
# 2782   0.339210    0.421053         0.300080        1.0
# 3791   0.132170    0.421053         0.695897        0.5
# ...         ...         ...              ...        ...
# 473    0.653898    0.894737         0.699920        0.5
# 3520   0.044919    0.368421         0.708769        0.0
# 1971   0.056247    0.894737         0.485921        0.5
# 1554   0.241948    0.263158         0.346742        0.5
# 3916   0.543700    0.315789         0.469831        0.5
#
#       taxa_crescimento_populacao  taxa_criminalidade  tempo_casos  \
# 1344                    1.000000            0.357009     0.409091
# 3752                    0.734809            0.629681     0.500000
# 252                     0.505882            0.592716     0.590909
# 2782                    0.788453            0.761870     0.045455
# 3791                    0.000000            0.463085     1.000000
# ...                          ...                 ...          ...
# 473                     0.000000            0.716779     0.454545
# 3520                    1.000000            0.608752     0.454545
# 1971                    0.275827            0.397234     0.772727
# 1554                    0.480452            0.748637     0.545455
# 3916                    0.884235            0.883733     1.000000
#
#       nivel_automacao  congestionamento  advogados  ...       idh  \
# 1344              0.2          1.000000   0.479592  ...  0.483792
# 3752              0.6          0.333333   0.326531  ...  0.822061
# 252               1.0          0.000000   0.265306  ...  0.300782
# 2782              0.0          0.000000   0.295918  ...  0.655066
# 3791              0.8          0.000000   0.438776  ...  0.551180
# ...               ...               ...        ...  ...       ...
# 473               0.2          0.000000   0.846939  ...  0.395808
# 3520              0.6          0.333333   0.071429  ...  0.666169
# 1971              0.4          0.333333   0.938776  ...  0.791313
# 1554              0.5          0.333333   0.795918  ...  0.491474
# 3916              0.7          0.333333   0.479592  ...  0.675057
#
#       idade_juizes_18-29  idade_juizes_30-39  idade_juizes_40-49  \
# 1344                 0.0                 0.0                 1.0
# 3752                 0.0                 0.0                 0.0
# 252                  0.0                 0.0                 0.0
# 2782                 0.0                 1.0                 0.0
# 3791                 0.0                 0.0                 1.0
# ...                  ...                 ...                 ...
# 473                  0.0                 0.0                 1.0
# 3520                 0.0                 0.0                 0.0
# 1971                 0.0                 0.0                 0.0
# 1554                 0.0                 1.0                 0.0
# 3916                 0.0                 1.0                 0.0
#
#       idade_juizes_50-59  idade_juizes_60-69  idade_juizes_70-79  \
# 1344                 0.0                 0.0                 0.0
# 3752                 1.0                 0.0                 0.0
# 252                  1.0                 0.0                 0.0
# 2782                 0.0                 0.0                 0.0
# 3791                 0.0                 0.0                 0.0
# ...                  ...                 ...                 ...
# 473                  0.0                 0.0                 0.0
# 3520                 1.0                 0.0                 0.0
# 1971                 1.0                 0.0                 0.0
# 1554                 0.0                 0.0                 0.0
# 3916                 0.0                 0.0                 0.0
#
#       idade_juizes_80-89  casos_pendentes  prediction_label
# 1344                 0.0         0.574819          0.617218
# 3752                 0.0         0.563517          0.555840
# 252                  0.0         0.767405          0.726935
# 2782                 0.0         0.257911          0.327226
# 3791                 0.0         0.699141          0.628185
# ...                  ...              ...               ...
# 473                  0.0         0.663653          0.650456
# 3520                 0.0         0.589512          0.645023
# 1971                 0.0         0.482595          0.467499
# 1554                 0.0         0.324593          0.355651
# 3916                 0.0         0.403707          0.464754
#
# [1302 rows x 23 columns]

# %%
mae_func = get_metrics().loc['mae', 'Score Function']
mse_func = get_metrics().loc['mse', 'Score Function']
rmse_func = get_metrics().loc['rmse', 'Score Function']
r2_func = get_metrics().loc['r2', 'Score Function']

mae = mae_func(predictions['prediction_label'], predictions['casos_pendentes'])
mse = mse_func(predictions['prediction_label'], predictions['casos_pendentes'])
r2 =  r2_func(predictions['prediction_label'], predictions['casos_pendentes'])
rmse = np.sqrt(mse)

metric_model = {
    'MODEL': str(best_model)+'+PyCaret ',
    'MAE': mae,
    'MSE': mse,
    'RMSE': rmse,
    'R2': r2
}

models_result.append(metric_model)

# %%
sns.histplot((predictions['casos_pendentes']-predictions['prediction_label']),bins=50);
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif

# %%
final_model = finalize_model(best_model)
save_model(final_model, '../models/automl/modelPyCaret')

# Carregando o modelo salvo
#loaded_model = load_model('./modelo/automl/modelPyCaret')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(include=['populacao', 'num_juizes',
#                                               'casos_recebidos', 'tipo_caso',
#                                               'taxa_crescimento_populacao',
#                                               'taxa_criminalidade',
#                                               'tempo_casos', 'nivel_automacao',
#                                               'congestionamento', 'advogados',
#                                               'urbanizacao', 'nivel_educacao',
#                                               'habitantes_por_juiz', 'idh',
#                                               'idade_juizes_18-29',
#                                               'idade_j...
#                                               'idade_juizes_40-49',
#                                               'idade_juizes_50-59',
#                                               'idade_juizes_60-69',
#                                               'idade_juizes_70-79',
#                                               'idade_juizes_80-89'],
#                                      transformer=SimpleImputer())),
#                  ('categorical_imputer',
#                   TransformerWrapper(include=[],
#                                      transformer=SimpleImputer(strategy='most_frequent'))),
#                  ('clean_column_names',
#                   TransformerWrapper(transformer=CleanColumnNames())),
#                  ('actual_estimator', HuberRegressor())]),
#  '../models/automl/modelPyCaret.pkl')

# %% [markdown]
# <div style="background-color: #f0f8ff; padding: 7px; border-radius: 10px;">
# <h3>TPOT (Tree-based Pipeline Optimization Tool)</h3>
# </div>
#
# Usa algoritmos genéticos para automatizar o processo de construção de pipelines de aprendizado de máquina. Ele explora várias combinações de pré-processamento, seleção de características e algoritmos de aprendizado.

# %%
from tpot import TPOTRegressor

modelTPOT = TPOTRegressor(generations=5, population_size=20, verbosity=2)
modelTPOT.fit(X_train, y_train)

predictions = modelTPOT.predict(X_test)
# Out:
# Optimization Progress:   0%|          | 0/120 [00:00<?, ?pipeline/s]
# Generation 1 - Current best internal CV score: -0.005224863343489264
#
# Generation 2 - Current best internal CV score: -0.005223799983307872
#
# Generation 3 - Current best internal CV score: -0.005223799983307872
#
# Generation 4 - Current best internal CV score: -0.005223799983307872
#
# Generation 5 - Current best internal CV score: -0.005223799983307872
#
# Best pipeline: ElasticNetCV(input_matrix, l1_ratio=1.0, tol=0.0001)

# %%
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
print('R2:', r2_score(y_test, predictions))
# Out:
# MAE: 0.055464271920163455
# MSE: 0.004948461226680707
# RMSE: 0.07034529996155185
# R2: 0.8012629594308533

# %%
# Exportar o pipeline
#modelTPOT.export('../models/automl/modelTPOT.py')

best_model = modelTPOT.fitted_pipeline_
dump(best_model, '../models/automl/modelTPOT.joblib')
# Out:
# ['../models/automl/modelTPOT.joblib']

# %%
sns.histplot((y_test-predictions),bins=50);
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif

# %%
pipeline = modelTPOT.fitted_pipeline_
last_step_name, last_step = pipeline.steps[-1]
mode_name = last_step.__class__.__name__

# %%
metric_model = {
    'MODEL': mode_name+'+TPOTRegressor',
    'MAE': metrics.mean_absolute_error(y_test, predictions),
    'MSE': metrics.mean_squared_error(y_test, predictions),
    'RMSE': np.sqrt(metrics.mean_squared_error(y_test, predictions)),
    'R2': r2_score(y_test, predictions)
}

models_result.append(metric_model)

# %% [markdown]
# <div style="background-color: #f0f8ff; padding: 7px; border-radius: 10px;">
# <h3>H2OAutoML</h3>
# </div>
#
# H2O.ai é uma plataforma de AutoML que oferece uma ampla gama de modelos de aprendizado de máquina, incluindo regressão, classificação, e métodos de ensemble. Ele permite comparar automaticamente vários modelos e otimizar seus hiperparâmetros. Tem ssuporte a modelos distribuídos, de grande escala e integração com Spark e outras plataformas.

# %%
import h2o
from h2o.automl import H2OAutoML

h2o.init()

train = h2o.H2OFrame(pd.concat([X_train, y_train], axis=1))
test = h2o.H2OFrame(pd.concat([X_test, y_test], axis=1))
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321..... not found.
# Attempting to start a local H2O server...
#   Java Version: openjdk version "11.0.23" 2024-04-16; OpenJDK Runtime Environment (build 11.0.23+9-post-Debian-1deb10u1); OpenJDK 64-Bit Server VM (build 11.0.23+9-post-Debian-1deb10u1, mixed mode, sharing)
#   Starting server from /home/nonrootuser/.local/lib/python3.11/site-packages/h2o/backend/bin/h2o.jar
#   Ice root: /tmp/tmpaj09flnc
#   JVM stdout: /tmp/tmpaj09flnc/h2o_unknownUser_started_from_python.out
#   JVM stderr: /tmp/tmpaj09flnc/h2o_unknownUser_started_from_python.err
#   Server is running at http://127.0.0.1:54321
# Connecting to H2O server at http://127.0.0.1:54321 ... successful.
# --------------------------  ----------------------------------
# H2O_cluster_uptime:         01 secs
# H2O_cluster_timezone:       Etc/UTC
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.46.0.4
# H2O_cluster_version_age:    1 month and 11 days
# H2O_cluster_name:           H2O_from_python_unknownUser_8ip4cb
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    7.795 Gb
# H2O_cluster_total_cores:    8
# H2O_cluster_allowed_cores:  8
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://127.0.0.1:54321
# H2O_connection_proxy:       {"http": null, "https": null}
# H2O_internal_security:      False
# Python_version:             3.11.4 final
# --------------------------  ----------------------------------
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%

# %%
X_train_ = X_train.columns.tolist() 
y_train_ = y_train.name           

aml = H2OAutoML(max_models=20, seed=1)
aml.train(x=X_train_, y=y_train_, training_frame=train)

# Obtém o melhor modelo
modelH2O = aml.leader

# Exibe a tabela de desempenho dos modelos
leaderboard = aml.leaderboard
print(leaderboard)
# Out:
# AutoML progress: |
# 22:14:40.128: _train param, Dropping bad and constant columns: [idade_juizes_18-29]
#
# █
# 22:14:46.99: _train param, Dropping bad and constant columns: [idade_juizes_18-29]
#
#
# 22:14:46.646: _train param, Dropping bad and constant columns: [idade_juizes_18-29]
#
# █
# 22:14:48.577: _train param, Dropping bad and constant columns: [idade_juizes_18-29]
#
# ███
# 22:14:52.26: _train param, Dropping bad and constant columns: [idade_juizes_18-29]
#
# █
# 22:14:56.545: _train param, Dropping bad and constant columns: [idade_juizes_18-29]
#
# █
# 22:14:57.413: _train param, Dropping bad and constant columns: [idade_juizes_18-29]
# 22:14:58.453: _train param, Dropping bad and constant columns: [idade_juizes_18-29]
#
# █
# 22:14:59.699: _train param, Dropping bad and constant columns: [idade_juizes_18-29]
# 22:15:00.616: _train param, Dropping bad and constant columns: [idade_juizes_18-29]
#
# ████
# 22:15:05.241: _train param, Dropping bad and constant columns: [idade_juizes_18-29]
#
# █
# 22:15:05.958: _train param, Dropping bad and constant columns: [idade_juizes_18-29]
#
# ████████████████████████████████████████████
# 22:18:50.878: _train param, Dropping unused columns: [idade_juizes_18-29]
# 22:18:51.495: _train param, Dropping unused columns: [idade_juizes_18-29]
#
# ██████| (done) 100%
# model_id                                                      rmse         mse        mae      rmsle    mean_residual_deviance
# GLM_1_AutoML_1_20240820_221440                           0.0723441  0.00523366  0.0552278  0.0495902                0.00523366
# StackedEnsemble_BestOfFamily_1_AutoML_1_20240820_221440  0.0724808  0.00525347  0.0553718  0.0496899                0.00525347
# StackedEnsemble_AllModels_1_AutoML_1_20240820_221440     0.0724846  0.00525402  0.0553658  0.049689                 0.00525402
# GBM_grid_1_AutoML_1_20240820_221440_model_2              0.0737932  0.00544544  0.0567093  0.050594                 0.00544544
# GBM_1_AutoML_1_20240820_221440                           0.0747005  0.00558016  0.0572311  0.0512736                0.00558016
# DeepLearning_grid_1_AutoML_1_20240820_221440_model_1     0.0755966  0.00571485  0.0579613  0.0518184                0.00571485
# GBM_2_AutoML_1_20240820_221440                           0.0757477  0.00573771  0.0583772  0.0519273                0.00573771
# GBM_5_AutoML_1_20240820_221440                           0.0761956  0.00580576  0.058693   0.05222                  0.00580576
# XRT_1_AutoML_1_20240820_221440                           0.0768785  0.0059103   0.058923   0.0528295                0.0059103
# DRF_1_AutoML_1_20240820_221440                           0.0769402  0.00591979  0.0593691  0.0529233                0.00591979
# [22 rows x 6 columns]

# %%
predictions = modelH2O.predict(test)

# Converte as previsões para um DataFrame pandas
predictions_df = h2o.as_list(predictions, use_pandas=True)
y_pred = predictions_df['predict']
# Out:
# glm prediction progress: |███████████████████████████████████████████████████████| (done) 100%

# %%
# Converte o conjunto de teste para um DataFrame pandas para comparação
test_df = h2o.as_list(test, use_pandas=True)
y_test_ = test_df["casos_pendentes"]

# %%
print('MAE:', metrics.mean_absolute_error(y_test_, y_pred))
print('MSE:', metrics.mean_squared_error(y_test_, y_pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test_, y_pred)))
print('R2:', r2_score(y_test_, y_pred))
# Out:
# MAE: 0.055599137187958225
# MSE: 0.004968625214359554
# RMSE: 0.07048847575568332
# R2: 0.8004531458233908

# %%
model_path = h2o.save_model(model=modelH2O, path="../models/automl", force=True)

# %%
sns.histplot((y_test_-y_pred),bins=50);
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif

# %%
metric_model = {
    'MODEL': modelH2O.model_id+'+h2o',
    'MAE': metrics.mean_absolute_error(y_test_, y_pred),
    'MSE': metrics.mean_squared_error(y_test_, y_pred),
    'RMSE': np.sqrt(metrics.mean_squared_error(y_test_, y_pred)),
    'R2': r2_score(y_test_, y_pred)
}

models_result.append(metric_model)

# %%
# Encerra a sessão H2O
h2o.shutdown(prompt=False)
# Out:
# H2O session _sid_ae72 closed.
